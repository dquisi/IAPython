# %% [markdown]
# # IBM Watson
#
# ## Instalacion y configuracion
#
# To install, use pip or easy_install:
#
# pip install --upgrade ibm-watson
#
#
# Note the following: a) Versions prior to 3.0.0 can be installed using:
#
# pip install --upgrade watson-developer-cloud

# %%
import json
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# ## Traducción dle lenguaje

# %%
authenticator = IAMAuthenticator('bYAflzALvlFROWuZwN5mb5SpZEtBYM8aTxg-2P1MhMR-')
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator)
language_translator.set_service_url('https://api.us-south.language-translator.watson.cloud.ibm.com/instances/8390ca50-4099-43e2-910e-c1f5e7cd41a5')

## Translate
translation = language_translator.translate(
    text='Hola mundo desde la UPS', model_id='es-en').get_result()
print(json.dumps(translation, indent=2, ensure_ascii=False))
# Out:
# {
#   "translations": [
#     {
#       "translation": "Hello world from the UPS"
#     }
#   ],
#   "word_count": 5,
#   "character_count": 23
# }

# %% [markdown]
# ## Identificaciones del lenguaje

# %%
 language = language_translator.identify(
     'Hola mundo desde la UPS').get_result()
 print(json.dumps(language, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "es",
#       "confidence": 0.9973528656840894
#     },
#     {
#       "language": "pt",
#       "confidence": 0.002586178118784105
#     },
#     {
#       "language": "eo",
#       "confidence": 4.151229417489329e-05
#     },
#     {
#       "language": "it",
#       "confidence": 8.31887683578887e-06
#     },
#     {
#       "language": "ca",
#       "confidence": 2.182430808711368e-06
#     },
#     {
#       "language": "fr",
#       "confidence": 2.147186661935608e-06
#     },
#     {
#       "language": "nn",
#       "confidence": 1.29401719581961e-06
#     },
#     {
#       "language": "en",
#       "confidence": 1.1868370982728207e-06
#     },
#     {
#       "language": "eu",
#       "confidence": 1.0397196458257516e-06
#     },
#     {
#       "language": "sv",
#       "confidence": 9.899563747907302e-07
#     },
#     {
#       "language": "nb",
#       "confidence": 5.789339145381322e-07
#     },
#     {
# ...

# %% [markdown]
# # Referencias
#
# https://github.com/watson-developer-cloud/python-sdk
# https://cloud.ibm.com/services/language-translator/crn%3Av1%3Abluemix%3Apublic%3Alanguage-translator%3Aus-south%3Aa%2Fc501502d7c0e476c85eaf35a4026e890%3A93d476f2-5b6f-41fe-bd7d-b614575823b7%3A%3A?paneId=manage
# https://cloud.ibm.com/apidocs/language-translator?code=python
